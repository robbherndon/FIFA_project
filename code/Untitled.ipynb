# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/Fifa_players.csv', index_col='id')
df.head()
# Out:
#         Name  Age Nationality  Overall_Rating  Potential                 Club  \
# id
# 1   L. Messi   30   Argentina              93         93         FC Barcelona
# 2     Neymar   25      Brazil              92         94  Paris Saint-Germain
# 4   M. Neuer   31     Germany              92         92     FC Bayern Munich
# 6     De Gea   26       Spain              90         92    Manchester United
# 8   T. Kroos   27     Germany              90         90       Real Madrid CF
#
#    Acceleration Aggression Agility Balance  ... Reactions Short passing  \
# id                                          ...
# 1            92         48      90      95  ...        95            88
# 2            94         56      96      82  ...        88            81
# 4            58         29      52      35  ...        85            55
# 6            57         38      60      43  ...        88            50
# 8            60         60      71      69  ...        86            90
#
# ...

# %%
df.shape
# Out:
# (7343, 41)

# %%
df.
